# %% [markdown]
# # <img src="https://files.training.databricks.com/images/DeltaLake-logo.png" width=80px> Managed Delta Lake
#
# Delta Lake&reg; managed and queried via the Databricks platform includes additional features and optimizations.
#
# These include:
#
# - **Optimize**
#
# - **Data skipping**
#
# - **Z-Order**
#
# - **Caching**
#
# <img src="https://www.evernote.com/l/AAGv1SuWeRNJM4TI4bIOyGNPm0CTHa17PLwB/image.png" width=900px>

# %% [markdown]
# ### Getting Started
#
# Run the following cell to configure our "classroom."

# %%
# %run ./Includes/Classroom-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Initialized classroom variables & functions...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets are already mounted to <b>/mnt/training</b> from <b>wasbs://training@dbtraineastus.blob.core.windows.net/</b>
# Created user-specific database
# Using the database <b style="color:green">vsekar_cloudseclab2_com_db</b>.
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# All done!

# %%
# %run ./Includes/Delta-Optimization-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("""
    DROP TABLE IF EXISTS iot_data
  """)
spark.sql("""
    CREATE TABLE iot_data
    USING DELTA
    LOCATION '{}/delta/iot-events/'
  """.format(userhome))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: DataFrame[]</div>

# %% [markdown]
# Set up relevant paths.

# %%
iotPath = userhome + "/delta/iot-events/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## SMALL FILE PROBLEM
#
# Historical and new data is often written in very small files and directories.
#
# This data may be spread across a data center or even across the world (that is, not co-located).
#
# The result is that a query on this data may be very slow due to
# * network latency
# * volume of file metatadata
#
# The solution is to compact many small files into one larger file.
# Delta Lake has a mechanism for compacting small files.

# %% [markdown]
# -sandbox
# ### OPTIMIZE
# Delta Lake supports the `OPTIMIZE` operation, which performs file compaction.
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> Small files are compacted together into new larger files up to 1GB.
# Thus, at this point the number of files increases!
#
# The 1GB size was determined by the Databricks optimization team as a trade-off between query speed and run-time performance when running Optimize.
#
# `OPTIMIZE` is not run automatically because you must collect many small files first.
#
# * Run `OPTIMIZE` more often if you want better end-user query performance
# * Since `OPTIMIZE` is a time consuming step, run it less often if you want to optimize cost of compute hours
# * To start with, run `OPTIMIZE` on a daily basis (preferably at night when spot prices are low), and determine the right frequency for your particular business case
# * In the end, the frequency at which you run `OPTIMIZE` is a business decision
#
# The easiest way to see what `OPTIMIZE` does is to perform a simple `count(*)` query before and after and compare the timing!

# %% [markdown]
# Take a look at the `iotPath + "/date=2018-06-01/" ` directory.
#
# Notice, in particular files like `../delta/iot-events/date=2018-07-26/part-xxxx.snappy.parquet`. There are hundreds of small files!

# %%
display(dbutils.fs.ls(iotPath + "/date=2016-07-26"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00000-dcb9d2d2-78f8-407b-ae07-5c8e4c41668a.c000.snappy.parquet</td><td>part-00000-dcb9d2d2-78f8-407b-ae07-5c8e4c41668a.c000.snappy.parquet</td><td>2638</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00001-0d606ce0-8e68-482b-92da-1e6924da549a.c000.snappy.parquet</td><td>part-00001-0d606ce0-8e68-482b-92da-1e6924da549a.c000.snappy.parquet</td><td>2524</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00002-cc05cc88-9d9e-440f-a3fb-57d7888cc18c.c000.snappy.parquet</td><td>part-00002-cc05cc88-9d9e-440f-a3fb-57d7888cc18c.c000.snappy.parquet</td><td>2530</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00003-5587c67e-f28c-416a-9586-4f59092a62aa.c000.snappy.parquet</td><td>part-00003-5587c67e-f28c-416a-9586-4f59092a62aa.c000.snappy.parquet</td><td>2575</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00004-3b569ae7-ddb3-499e-b0c8-b3b0a73d0bf3.c000.snappy.parquet</td><td>part-00004-3b569ae7-ddb3-499e-b0c8-b3b0a73d0bf3.c000.snappy.parquet</td><td>2499</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00005-1ae09d4a-9aae-4b9f-9c70-ecdb22858029.c000.snappy.parquet</td><td>part-00005-1ae09d4a-9aae-4b9f-9c70-ecdb22858029.c000.snappy.parquet</td><td>2498</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00006-559ce812-4567-423c-b871-bef0f381ab8c.c000.snappy.parquet</td><td>part-00006-559ce812-4567-423c-b871-bef0f381ab8c.c000.snappy.parquet</td><td>2560</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00007-00d92706-54f3-42c7-b09f-d570eee2b6d8.c000.snappy.parquet</td><td>part-00007-00d92706-54f3-42c7-b09f-d570eee2b6d8.c000.snappy.parquet</td><td>2595</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00008-281b7976-e916-489e-b844-50b74690d7ab.c000.snappy.parquet</td><td>part-00008-281b7976-e916-489e-b844-50b74690d7ab.c000.snappy.parquet</td><td>2615</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00009-74271a5c-df26-4807-8d5c-3e9a7c748d4b.c000.snappy.parquet</td><td>part-00009-74271a5c-df26-4807-8d5c-3e9a7c748d4b.c000.snappy.parquet</td><td>2570</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00010-4b138a20-62df-4026-b97c-bc624fa0198a.c000.snappy.parquet</td><td>part-00010-4b138a20-62df-4026-b97c-bc624fa0198a.c000.snappy.parquet</td><td>2590</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00011-2e15d928-29f0-4c84-ab63-59d09f81da94.c000.snappy.parquet</td><td>part-00011-2e15d928-29f0-4c84-ab63-59d09f81da94.c000.snappy.parquet</td><td>2624</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00012-84dd8a21-967a-4e84-8961-f2710c063de0.c000.snappy.parquet</td><td>part-00012-84dd8a21-967a-4e84-8961-f2710c063de0.c000.snappy.parquet</td><td>2608</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00013-7375cf07-3fbc-4a3e-b0ec-d23cd9f169ae.c000.snappy.parquet</td><td>part-00013-7375cf07-3fbc-4a3e-b0ec-d23cd9f169ae.c000.snappy.parquet</td><td>2576</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00014-fe499ee6-d61c-4e71-8a56-7fa0a9abc1a9.c000.snappy.parquet</td><td>part-00014-fe499ee6-d61c-4e71-8a56-7fa0a9abc1a9.c000.snappy.parquet</td><td>2560</td></tr><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events/date=2016-07-26/part-00015-26cb98bb-90f1-4572-88f5-88f53d300121.c000.snappy.parquet</td><td>part-00015-26cb98bb-90f1-4572-88f5-88f53d300 ...

# %% [markdown]
# CAUTION: Run this query. Notice it is very slow, due to the number of small files.

# %%
# %sql
SELECT * FROM iot_data where deviceId=92
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>time</th><th>date</th><th>deviceId</th></tr></thead><tbody><tr><td>Open</td><td>1469659034</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469657848</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469654974</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469619416</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469603294</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469579226</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469642645</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469602079</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469617250</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469634692</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469620446</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469600928</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469649277</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469610393</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469616260</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469610943</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469579269</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469652094</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469594177</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469632519</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469585992</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469587231</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469608398</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469610665</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469628228</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469614108</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469661521</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469621442</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469610128</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469622455</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469607492</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469617201</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469632502</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469590514</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469595581</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469613609</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469614924</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469639727</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469581535</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469591346</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469643775</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469615393</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469598186</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469641497</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469657940</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469621512</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469632816</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469580117</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469585793</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469638686</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469593319</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469663439</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469641741</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</t ...

# %% [markdown]
# -sandbox
# ### Data Skipping and ZORDER
#
# Delta Lake uses two mechanisms to speed up queries.
#
# <b>Data Skipping</b> is a performance optimization that aims at speeding up queries that contain filters (WHERE clauses).
#
# For example, we have a data set that is partitioned by `date`.
#
# A query using `WHERE date > 2016-07-26` would not access data that resides in partitions that correspond to dates prior to `2016-07-26`.
#
# <b>ZOrdering</b> is a technique to colocate related information in the same set of files.
#
# ZOrdering maps multidimensional data to one dimension while preserving locality of the data points.
#
# Given a column that you want to perform ZORDER on, say `OrderColumn`, Delta
# * takes existing parquet files within a partition
# * maps the rows within the parquet files according to `OrderColumn` using the algorithm described <a href="https://en.wikipedia.org/wiki/Z-order_curve" target="_blank">here</a>
# * (in the case of only one column, the mapping above becomes a linear sort)
# * rewrites the sorted data into new parquet files
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> You cannot use the partition column also as a ZORDER column.

# %% [markdown]
# #### ZORDER Technical Overview
#
# A brief example of how this algorithm works (refer to [this blog](https://databricks.com/blog/2018/07/31/processing-petabytes-of-data-in-seconds-with-databricks-delta.html) for more details):
#
# ![](https://files.training.databricks.com/images/adbcore/zorder.png)
#
# Legend:
# - Gray dot = data point e.g., chessboard square coordinates
# - Gray box = data file; in this example, we aim for files of 4 points each
# - Yellow box = data file that’s read for the given query
# - Green dot = data point that passes the query’s filter and answers the query
# - Red dot = data point that’s read, but doesn’t satisfy the filter; “false positive”

# %% [markdown]
# -sandbox
#
#
# #### ZORDER example
# In the image below, table `Students` has 4 columns:
# * `gender` with 2 distinct values
# * `Pass-Fail` with 2 distinct values
# * `Class` with 4 distinct values
# * `Student` with many distinct values
#
# Suppose you wish to perform the following query:
#
# ```SELECT Name FROM Students WHERE gender = 'M' AND Pass_Fail = 'P' AND Class = 'Junior'```
#
# ```ORDER BY Gender, Pass_Fail```
#
# The most effective way of performing that search is to order the data starting with the largest set, which is `Gender` in this case.
#
# If you're searching for `gender = 'M'`, then you don't even have to look at students with `gender = 'F'`.
#
# Note that this technique only works if all `gender = 'M'` values are co-located.
#
#
# <div><img src="https://files.training.databricks.com/images/eLearning/Delta/zorder.png" style="height: 300px"/></div><br/>

# %% [markdown]
# #### ZORDER usage
#
# With Delta Lake the notation is:
#
# > `OPTIMIZE Students`<br>
# `ZORDER BY Gender, Pass_Fail`
#
# This will ensure all the data backing `Gender = 'M' ` is colocated, then data associated with `Pass_Fail = 'P' ` is colocated.
#
# See References below for more details on the algorithms behind ZORDER.
#
# Using ZORDER, you can order by multiple columns as a comma separated list; however, the effectiveness of locality drops.
#
# In streaming, where incoming events are inherently ordered (more or less) by event time, use `ZORDER` to sort by a different column, say 'userID'.

# %%
# %sql
OPTIMIZE iot_data
ZORDER by (deviceId)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>null</td><td>List(3, 600, List(64616, 261231, 182767.0, 3, 548301), List(1309, 2912, 2267.9533333333334, 600, 1360772), 3, List(minCubeSize(107374182400), List(0, 0), List(600, 1360772), 0, List(600, 1360772), 3, null), 1, 600, 0, false)</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM iot_data WHERE deviceId=92
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>time</th><th>date</th><th>deviceId</th></tr></thead><tbody><tr><td>Open</td><td>1469659034</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469657848</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469654974</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469619416</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469603294</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469579226</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469642645</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469602079</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469617250</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469634692</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469620446</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469600928</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469649277</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469610393</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469616260</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469610943</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469579269</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469652094</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469594177</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469632519</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469585992</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469587231</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469608398</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469610665</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469628228</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469614108</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469661521</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469621442</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469610128</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469622455</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469607492</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469617201</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469632502</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469590514</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469595581</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469613609</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469614924</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469639727</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469581535</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469591346</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469643775</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469615393</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469598186</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469641497</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469657940</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469621512</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469632816</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469580117</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469585793</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469638686</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469593319</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</td><td>1469663439</td><td>2016-07-27</td><td>92</td></tr><tr><td>Close</td><td>1469641741</td><td>2016-07-27</td><td>92</td></tr><tr><td>Open</t ...

# %% [markdown]
# -sandbox
# ## VACUUM
#
# To save on storage costs you should occasionally clean up invalid files using the `VACUUM` command.
#
# Invalid files are small files compacted into a larger file with the `OPTIMIZE` command.
#
# The  syntax of the `VACUUM` command is
# >`VACUUM name-of-table RETAIN number-of HOURS;`
#
# The `number-of` parameter is the <b>retention interval</b>, specified in hours.
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> Databricks does not recommend you set a retention interval shorter than seven days because old snapshots and uncommitted files can still be in use by concurrent readers or writers to the table.
#
# The scenario here is:
# 0. User A starts a query off uncompacted files, then
# 0. User B invokes a `VACUUM` command, which deletes the uncompacted files
# 0. User A's query fails because the underlying files have disappeared
#
# Invalid files can also result from updates/upserts/deletions.
#
# More details are provided here: <a href="https://docs.databricks.com/delta/optimizations.html#garbage-collection" target="_blank"> Garbage Collection</a>.

# %%
len(dbutils.fs.ls(iotPath + "date=2016-07-26"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 201</div>

# %% [markdown]
# -sandbox
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> In the example below we set off an immediate `VACUUM` operation with an override of the retention check so that all files are cleaned up immediately.
#
# Do not do this in production!
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> If using Databricks Runtime 5.1, in order to use a retention time of 0 hours, the following flag must be set.

# %%
spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

VACUUM iot_data RETAIN 0 HOURS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>dbfs:/user/vsekar@cloudseclab2.com/delta/iot-events</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> Notice how the directory looks vastly cleaned up!

# %%
len(dbutils.fs.ls(iotPath + "date=2016-07-26"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: 1</div>

# %% [markdown]
# ## Summary
# Delta Lake offers key features that allow for query optimization and garbage collection, resulting in improved performance.

# %% [markdown]
# ## Additional Topics & Resources
#
# * <a href="https://docs.databricks.com/delta/optimizations.html#" target="_blank">Optimizing Performance and Cost</a>
# * <a href="http://parquet.apache.org/documentation/latest/" target="_blank">Parquet Metadata</a>
# * <a href="https://en.wikipedia.org/wiki/Z-order_curve" target="_blank">Z-Order Curve</a>
