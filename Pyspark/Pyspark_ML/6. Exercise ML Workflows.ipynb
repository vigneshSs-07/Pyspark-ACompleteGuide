# %% [markdown]
# ## Exercise: ML Workflows
#
# Do a train/test split on a Dataset, create a baseline model, and evaluate the result.  Optionally, try to beat this baseline model by training a linear regression model.

# %% [markdown]
# Run the following cell to set up our environment.

# %%
# %run "../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ### Step 1: Train/Test Split
#
# Import the bike sharing dataset and take a look at what's in it.  This dataset contains number of bikes rented (`cnt`) by season, year, month, and hour and for a number of weather conditions.

# %%
bikeDF = (spark
  .read
  .option("header", True)
  .option("inferSchema", True)
  .csv("/mnt/training/bikeSharing/data-001/hour.csv")
  .drop("instant", "dteday", "casual", "registered", "holiday", "weekday") # Drop unnecessary features
)

display(bikeDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season</th><th>yr</th><th>mnth</th><th>hr</th><th>workingday</th><th>weathersit</th><th>temp</th><th>atemp</th><th>hum</th><th>windspeed</th><th>cnt</th></tr></thead><tbody><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0.24</td><td>0.2879</td><td>0.81</td><td>0.0</td><td>16</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>1</td><td>0.22</td><td>0.2727</td><td>0.8</td><td>0.0</td><td>40</td></tr><tr><td>1</td><td>0</td><td>1</td><td>2</td><td>0</td><td>1</td><td>0.22</td><td>0.2727</td><td>0.8</td><td>0.0</td><td>32</td></tr><tr><td>1</td><td>0</td><td>1</td><td>3</td><td>0</td><td>1</td><td>0.24</td><td>0.2879</td><td>0.75</td><td>0.0</td><td>13</td></tr><tr><td>1</td><td>0</td><td>1</td><td>4</td><td>0</td><td>1</td><td>0.24</td><td>0.2879</td><td>0.75</td><td>0.0</td><td>1</td></tr><tr><td>1</td><td>0</td><td>1</td><td>5</td><td>0</td><td>2</td><td>0.24</td><td>0.2576</td><td>0.75</td><td>0.0896</td><td>1</td></tr><tr><td>1</td><td>0</td><td>1</td><td>6</td><td>0</td><td>1</td><td>0.22</td><td>0.2727</td><td>0.8</td><td>0.0</td><td>2</td></tr><tr><td>1</td><td>0</td><td>1</td><td>7</td><td>0</td><td>1</td><td>0.2</td><td>0.2576</td><td>0.86</td><td>0.0</td><td>3</td></tr><tr><td>1</td><td>0</td><td>1</td><td>8</td><td>0</td><td>1</td><td>0.24</td><td>0.2879</td><td>0.75</td><td>0.0</td><td>8</td></tr><tr><td>1</td><td>0</td><td>1</td><td>9</td><td>0</td><td>1</td><td>0.32</td><td>0.3485</td><td>0.76</td><td>0.0</td><td>14</td></tr><tr><td>1</td><td>0</td><td>1</td><td>10</td><td>0</td><td>1</td><td>0.38</td><td>0.3939</td><td>0.76</td><td>0.2537</td><td>36</td></tr><tr><td>1</td><td>0</td><td>1</td><td>11</td><td>0</td><td>1</td><td>0.36</td><td>0.3333</td><td>0.81</td><td>0.2836</td><td>56</td></tr><tr><td>1</td><td>0</td><td>1</td><td>12</td><td>0</td><td>1</td><td>0.42</td><td>0.4242</td><td>0.77</td><td>0.2836</td><td>84</td></tr><tr><td>1</td><td>0</td><td>1</td><td>13</td><td>0</td><td>2</td><td>0.46</td><td>0.4545</td><td>0.72</td><td>0.2985</td><td>94</td></tr><tr><td>1</td><td>0</td><td>1</td><td>14</td><td>0</td><td>2</td><td>0.46</td><td>0.4545</td><td>0.72</td><td>0.2836</td><td>106</td></tr><tr><td>1</td><td>0</td><td>1</td><td>15</td><td>0</td><td>2</td><td>0.44</td><td>0.4394</td><td>0.77</td><td>0.2985</td><td>110</td></tr><tr><td>1</td><td>0</td><td>1</td><td>16</td><td>0</td><td>2</td><td>0.42</td><td>0.4242</td><td>0.82</td><td>0.2985</td><td>93</td></tr><tr><td>1</td><td>0</td><td>1</td><td>17</td><td>0</td><td>2</td><td>0.44</td><td>0.4394</td><td>0.82</td><td>0.2836</td><td>67</td></tr><tr><td>1</td><td>0</td><td>1</td><td>18</td><td>0</td><td>3</td><td>0.42</td><td>0.4242</td><td>0.88</td><td>0.2537</td><td>35</td></tr><tr><td>1</td><td>0</td><td>1</td><td>19</td><td>0</td><td>3</td><td>0.42</td><td>0.4242</td><td>0.88</td><td>0.2537</td><td>37</td></tr><tr><td>1</td><td>0</td><td>1</td><td>20</td><td>0</td><td>2</td><td>0.4</td><td>0.4091</td><td>0.87</td><td>0.2537</td><td>36</td></tr><tr><td>1</td><td>0</td><td>1</td><td>21</td><td>0</td><td>2</td><td>0.4</td><td>0.4091</td><td>0.87</td><td>0.194</td><td>34</td></tr><tr><td>1</td><td>0</td><td>1</td><td>22</td><td>0</td><td>2</td><td>0.4</td><td>0.4091</td><td>0.94</td><td>0.2239</td><td>28</td></tr><tr><td>1</td><td>0</td><td>1</td><td>23</td><td>0</td><td>2</td><td>0.46</td><td>0.4545</td><td>0.88</td><td>0.2985</td><td>39</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>2</td><td>0.46</td><td>0.4545</td><td>0.88</td><td>0.2985</td><td>17</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>2</td><td>0.44</td><td>0.4394</td><td>0.94</td><td>0.2537</td><td>17</td></tr><tr><td>1</td><td>0</td><td>1</td><td>2</td><td>0</td><td>2</td><td>0.42</td><td>0.4242</td><td>1.0</td><td>0.2836</td><td>9</td></tr><tr><td>1</td><td>0</td><td>1</td><td>3</td><td>0</td><td>2</t ...

# %% [markdown]
# Perform a train/test split.  Put 70% of the data into `trainBikeDF` and 30% into `testBikeDF`.  Use a seed of `42` so you have the same split every time you perform the operation.

# %%
# ANSWER
trainBikeDF, testBikeDF = bikeDF.randomSplit([0.7, 0.3], seed=42)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TEST - Run this cell to test your solution
_traincount = trainBikeDF.count()
_testcount = testBikeDF.count()

dbTest("ML1-P-03-01-01", True, _traincount < 13000 and _traincount > 12000)
dbTest("ML1-P-03-01-02", True, _testcount < 5500 and _testcount > 4800)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3013059022291227&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> _testcount <span class="ansi-blue-fg">=</span> testBikeDF<span class="ansi-blue-fg">.</span>count<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>
# <span class="ansi-green-fg">----&gt; 5</span><span class="ansi-red-fg"> </span>dbTest<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ML1-P-03-01-01&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span> _traincount <span class="ansi-blue-fg">&lt;</span> <span class="ansi-cyan-fg">13000</span> <span class="ansi-green-fg">and</span> _traincount <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">12000</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      6</span> dbTest<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ML1-P-03-01-02&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span> _testcount <span class="ansi-blue-fg">&lt;</span> <span class="ansi-cyan-fg">5500</span> <span class="ansi-green-fg">and</span> _testcount <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">4800</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      7</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dbTest&#39; is not defined</div>

# %% [markdown]
# ### Step 2: Create a Baseline Model
#
# Calculate the average of the column `cnt` and save it to the variable `trainCnt`.  Then create a new DataFrame `bikeTestPredictionDF` that appends a new column `prediction` that's the value of `trainCnt`.

# %%
# ANSWER
from pyspark.sql.functions import avg, lit

avgTrainCnt = trainBikeDF.select(avg("cnt")).first()[0]
bikeTestPredictionDF = testBikeDF.withColumn("prediction", lit(avgTrainCnt))

display(bikeTestPredictionDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>season</th><th>yr</th><th>mnth</th><th>hr</th><th>workingday</th><th>weathersit</th><th>temp</th><th>atemp</th><th>hum</th><th>windspeed</th><th>cnt</th><th>prediction</th></tr></thead><tbody><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0.1</td><td>0.0758</td><td>0.42</td><td>0.3881</td><td>25</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>0.24</td><td>0.2879</td><td>0.81</td><td>0.0</td><td>16</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>2</td><td>0.18</td><td>0.197</td><td>0.51</td><td>0.1642</td><td>25</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>0</td><td>2</td><td>0.2</td><td>0.197</td><td>0.47</td><td>0.2239</td><td>17</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>1</td><td>0.12</td><td>0.1364</td><td>0.5</td><td>0.194</td><td>14</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>1</td><td>0.14</td><td>0.1212</td><td>0.59</td><td>0.2836</td><td>7</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>1</td><td>0.14</td><td>0.1667</td><td>0.59</td><td>0.1045</td><td>12</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>1</td><td>0.22</td><td>0.197</td><td>0.44</td><td>0.3582</td><td>5</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>2</td><td>0.16</td><td>0.1364</td><td>0.69</td><td>0.2836</td><td>9</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>2</td><td>0.2</td><td>0.197</td><td>0.64</td><td>0.194</td><td>17</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>2</td><td>0.2</td><td>0.2121</td><td>0.75</td><td>0.1343</td><td>9</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>0</td><td>1</td><td>2</td><td>0.24</td><td>0.2273</td><td>0.7</td><td>0.2537</td><td>21</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>1</td><td>0.04</td><td>0.0758</td><td>0.57</td><td>0.1045</td><td>13</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>1</td><td>0.1</td><td>0.0606</td><td>0.42</td><td>0.4627</td><td>12</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>1</td><td>0.22</td><td>0.2273</td><td>0.64</td><td>0.194</td><td>20</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>1</td><td>0.26</td><td>0.2727</td><td>0.56</td><td>0.1343</td><td>23</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>2</td><td>0.04</td><td>0.0</td><td>0.41</td><td>0.3881</td><td>12</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>0</td><td>2</td><td>0.44</td><td>0.4394</td><td>0.94</td><td>0.2537</td><td>17</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td><td>0.12</td><td>0.1212</td><td>0.5</td><td>0.2836</td><td>1</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td><td>0.14</td><td>0.1212</td><td>0.5</td><td>0.2836</td><td>2</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td><td>0.16</td><td>0.1818</td><td>0.59</td><td>0.1045</td><td>2</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td><td>0.16</td><td>0.197</td><td>0.74</td><td>0.0896</td><td>6</td><td>188.89937878044793</td></tr><tr><td>1</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td><td>0.16</td><td>0.2273</td><td>0.64</td><td>0.0</td><td>4</td><td>188 ...

# %%
# TEST - Run this cell to test your solution
dbTest("ML1-P-03-02-01", True, avgTrainCnt < 195 and avgTrainCnt > 180)
dbTest("ML1-P-03-02-02", True, "prediction" in bikeTestPredictionDF.columns)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3013059022291230&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># TEST - Run this cell to test your solution</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>dbTest<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ML1-P-03-02-01&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span> avgTrainCnt <span class="ansi-blue-fg">&lt;</span> <span class="ansi-cyan-fg">195</span> <span class="ansi-green-fg">and</span> avgTrainCnt <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">180</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> dbTest<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ML1-P-03-02-02&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;prediction&#34;</span> <span class="ansi-green-fg">in</span> bikeTestPredictionDF<span class="ansi-blue-fg">.</span>columns<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;Tests passed!&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dbTest&#39; is not defined</div>

# %% [markdown]
# -sandbox
# ### Step 3: Evaluate the Result
#
# Evaluate the result using `mse` as the error metric.  Save the result to `testError`.
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** Your baseline prediction will not be very accurate.  Be sure to take the square root of the MSE to return the results to the proper units (that is, bike counts).

# %%
# ANSWER
from pyspark.ml.evaluation import RegressionEvaluator

evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="cnt", metricName="mse")
testError = evaluator.evaluate(bikeTestPredictionDF)

print("Error on the test set for the baseline model: {}".format(testError))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Error on the test set for the baseline model: 33098.35537800063
# </div>

# %%
# TEST - Run this cell to test your solution
dbTest("ML1-P-03-03-01", True, testError > 33000 and testError < 35000)

print("Tests passed!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3013059022291233&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># TEST - Run this cell to test your solution</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>dbTest<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ML1-P-03-03-01&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">,</span> testError <span class="ansi-blue-fg">&gt;</span> <span class="ansi-cyan-fg">33000</span> <span class="ansi-green-fg">and</span> testError <span class="ansi-blue-fg">&lt;</span> <span class="ansi-cyan-fg">35000</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;Tests passed!&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;dbTest&#39; is not defined</div>

# %% [markdown]
# ### Step 4 (Optional): Beat the Baseline
#
# Use a linear regression model (explored in the previous lesson) to beat the baseline model score.
